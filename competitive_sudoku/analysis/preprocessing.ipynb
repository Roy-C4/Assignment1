# %%
import pandas as pd

# %%
data = pd.read_csv('greedy-random-2x3-3x3/outfile-random-2x3-custom-greedy-0.1.txt', sep=",").reset_index()
# data.columns = ["Player1", "Player2", "Board", "Time", "Score", "Winner"]

# %%
# data['Score'] = data['Time'] + data['Score']

# %%
data
# Out:
#     index  Player1      Player2  Board Time Score  Winner
# 0  Custom   Greedy   random-2x3    0.1   [0    0]       2
# 1  Custom   Greedy   random-2x3    0.1   [0    0]       2
# 2  Custom   Greedy   random-2x3    0.1   [0    0]       2
# 3  Custom   Greedy   random-2x3    0.1   [0    1]       2
# 4  Custom   Greedy   random-2x3    0.1   [0    1]       2
# 5  Custom   Greedy   random-2x3    0.1   [1    3]       1
# 6  Custom   Greedy   random-2x3    0.1   [0    0]       2
# 7  Custom   Greedy   random-2x3    0.1   [0    0]       2
# 8  Custom   Greedy   random-2x3    0.1   [0    0]       2
# 9  Custom   Greedy   random-2x3    0.1   [0    0]       2

# %%
data.columns=[" ", " ", " ", " ", " ", " ", " "]

# %%
# data["Score"] = data.iloc[:, 4:5] + data.iloc[:, 5:6]

# %%
data.columns=["Player1", "Player2", "Board", "Time", "Score1", "Score2", "Winner"]

# %%
data = data.drop(["Remove"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [131], in <module>
# ----> 1 data = data.drop(["Remove"], axis=1)
#
# File ~\Anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
#    4783     errors: str = "raise",
#    4784 ):
#    4785     """
# ...

# %%
data
# Out:
#   Player1  Player2        Board  Time Score1 Score2  Winner
# 0  Custom   Greedy   random-2x3   0.1     [0     0]       2
# 1  Custom   Greedy   random-2x3   0.1     [0     0]       2
# 2  Custom   Greedy   random-2x3   0.1     [0     0]       2
# 3  Custom   Greedy   random-2x3   0.1     [0     1]       2
# 4  Custom   Greedy   random-2x3   0.1     [0     1]       2
# 5  Custom   Greedy   random-2x3   0.1     [1     3]       1
# 6  Custom   Greedy   random-2x3   0.1     [0     0]       2
# 7  Custom   Greedy   random-2x3   0.1     [0     0]       2
# 8  Custom   Greedy   random-2x3   0.1     [0     0]       2
# 9  Custom   Greedy   random-2x3   0.1     [0     0]       2

# %%
data["Score1"] = data["Score1"].str.replace("[", "")
data["Score2"] = data["Score2"].str.replace("]", "")
# Out:
# C:\Users\20181819\AppData\Local\Temp\ipykernel_14784\602331098.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Score1"] = data["Score1"].str.replace("[", "")
# C:\Users\20181819\AppData\Local\Temp\ipykernel_14784\602331098.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Score2"] = data["Score2"].str.replace("]", "")

# %%
data["Score1"] = data["Score1"].astype(int)
data["Score2"] = data["Score2"].astype(int)
data["Time"] = data["Time"].astype(float)
data["Winner"] = data["Winner"].astype(int)

# %%
data
# Out:
#   Player1  Player2        Board  Time  Score1  Score2  Winner
# 0  Custom   Greedy   random-2x3   0.1       0       0       2
# 1  Custom   Greedy   random-2x3   0.1       0       0       2
# 2  Custom   Greedy   random-2x3   0.1       0       0       2
# 3  Custom   Greedy   random-2x3   0.1       0       1       2
# 4  Custom   Greedy   random-2x3   0.1       0       1       2
# 5  Custom   Greedy   random-2x3   0.1       1       3       1
# 6  Custom   Greedy   random-2x3   0.1       0       0       2
# 7  Custom   Greedy   random-2x3   0.1       0       0       2
# 8  Custom   Greedy   random-2x3   0.1       0       0       2
# 9  Custom   Greedy   random-2x3   0.1       0       0       2
